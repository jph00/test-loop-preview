# %% [raw]
# ---
# execute:
#   enabled: true
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import datetime

# %%
print(f'time = {datetime.datetime.now()}')
# Out:
# time = 2022-09-14 14:14:32.426054
